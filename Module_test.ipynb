# %%
import Hisat_Genotype_Analyzer_Module

# %%
dir(Hisat_Genotype_Analyzer_Module)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'hisat_genotype_analyzer',
#  'pd',
#  'plot_variants',
#  'plt',
#  'read_and_filter',
#  'sns',
#  'write_2_excel']

# %%
Hisat_Genotype_Analyzer_Module.hisat_genotype_analyzer('NA12877.hla.report.txt', 'plot', genes='A')
